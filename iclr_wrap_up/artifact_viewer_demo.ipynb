# %% [markdown]
# Import the ArtifactLoader and instantiate it.

# %%
from iclr_wrap_up.artifact_viewer import ArtifactLoader

# %%
loader = ArtifactLoader()

# %% [markdown]
# Look up the experiment id in sacredboard. It is in the first column under `Id`. This way you can retrieve all artifacts related to an experiment. `.load()` returns a dictionary mapping artifact names to `Artifact` objects.

# %%
artifacts = loader.load(experiment_id=508)
artifacts
# Out:
# {'infoplane': Artifact(name=infoplane),
#  'snr': Artifact(name=snr),
#  'infoplane_movie': Artifact(name=infoplane_movie)}

# %% [markdown]
# The `Artifact` objects support a `.show()` and a `.save()` method. `.show()` will display the the figure, `.save()` will save the artifact to your filesystem. The viewer will work only on `png` images for now.

# %%
artifacts['infoplane'].show()

# %%
artifacts['snr'].show()
